# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('iris.csv')

df.head()

X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y = df['species']

plt.figure(figsize=(20, 10))
sns.scatterplot(X, s=200)
# Out:
# <AxesSubplot: >

# %%
# let's generate principal components of the data

x_standardized  = StandardScaler().fit_transform(X)

features = x_standardized.T

cov_matrix = np.cov(features)

eigen_values, eigen_vectors = np.linalg.eig(cov_matrix)

proj_1 = x_scaled.dot(eigen_vectors.T[0])
proj_2 = x_scaled.dot(eigen_vectors.T[1])

print("Eigen vector size: ", len(eigen_vectors))

res = pd.DataFrame(proj_1, columns=['PC1'])
res['PC2'] = proj_2

res.head()
# Out:
# Eigen vector size:  4
#         PC1       PC2
# 0 -2.264542 -0.505704
# 1 -2.086426  0.655405
# 2 -2.367950  0.318477
# 3 -2.304197  0.575368
# 4 -2.388777 -0.674767

# %%
sns.scatterplot(res['PC1'], s=200)
# Out:
# <AxesSubplot: ylabel='PC1'>

# %%
# Check with both PC values and see the result
sns.scatterplot(res, s=200)
# Out:
# <AxesSubplot: >
